# %% [markdown]
# <a href="https://colab.research.google.com/github/HgVv19/Probyestadistica/blob/main/Unidad1/Practica_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *
# lista de calificaciones del grupo a probabilidad y estsadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print("el promedio del grupo es =>", mean(grupoa))
mediana = median(grupoa)
print("la mediana del grupo es =>", mediana)
moda = mode("grupoa")
print("la moda del grupo es =>", moda)
#cuando hay mas de una moda se pone multimodas en lugar de moda
[70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

moda2  = multimode(grupoa)
print(moda2)
# Out:
# el promedio del grupo es => 75.33333333333333
# la mediana del grupo es => 76.5
# la moda del grupo es => g
# [70, 100]

# %%
from statistics import *
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)
print("el tiempo promedio de los corredores es =>", mean(tiempos100mts))
mediana = median(tiempos100mts)
print("la mediana de los tiempos es =>", mediana)
moda = mode(tiempos100mts)
print("la moda de los tiempos es =>", moda)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es => 17.322
# la mediana de los tiempos es => 17.2
# la moda de los tiempos es => 15.1

# %%
from statistics import *
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

print(tiempos100mts)
print("el tiempo promedio de los corredores es =>", mediana)
moda = mode (tiempos100mts)
print("la moda de los tiempos es =>", moda)

import random
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)

import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
media1 = mean(fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)
print("la media de la fabrica 1 es =>", media1)
print("la mediana de la fabrica 1 es =>", mediana1)
print("la moda de la fabrica 1 es =>", moda1)




import random
fabrica2 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)

import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
media2 = mean(fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)
print("la media de la fabrica 2 es =>", media2)
print("la mediana de la fabrica 2 es =>", mediana2)
print("la moda de la fabrica 2 es =>", moda2)

fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es => 76.5
# la moda de los tiempos es => 15.1
# [54.76, 70.15, 99.37, 58.04, 66.5, 59.41, 94.04, 82.67, 61.12, 80.97, 76.36, 78.84, 98.28, 66.75, 79.34, 74.03, 50.81, 96.36, 92.53, 53.29, 54.16, 67.44, 61.19, 73.43, 52.43, 79.73, 58.7, 92.96, 60.41, 92.36, 56.28, 65.78, 96.23, 67.19, 89.43, 51.63, 88.86, 54.49, 74.71, 67.95, 89.93, 90.66, 73.51, 59.33, 67.96, 53.43, 75.06, 93.93, 75.8, 65.32, 80.22, 97.79, 61.79, 79.43, 71.86, 90.4, 74.96, 62.92, 51.05, 93.09, 67.59, 76.93, 74.27, 94.22, 87.72, 87.03, 69.27, 91.98, 57.88, 55.21, 75.83, 74.29, 61.68, 87.02, 53.21, 51.87, 50.19, 77.43, 94.59, 54.07, 75.43, 58.86, 97.6, 92.21, 64.39, 69.35, 97.48, 61.09, 65.19, 91.06, 66.44, 71.53, 74.38, 90.64, 65.59, 93.7, 63.3, 63.1, 56.31, 94.88]
# la media de la fabrica 1 es => 73.6223
# la mediana de la fabrica 1 es => 73.47
# la moda de la fabrica 1 es => 54.76
# [88.73, 71.1, 52.79, 91.97, 94.99, 78.24, 75.48, 78.17, 61.04, 51.3, 71.0, 77.83, 97.36, 99.19, 50.87, 71.86, 52.0, 52.26, 89.94, 77.34, 73.19, 72.28, 53.77, 64.63, 99.09, 67.13, 52.74, 77.29, 83.4, 78.51, 61.98, 54.57, 95.33, 85.21, 94.24, 76.57, 54.05, 50.11, 93.9, 58.43, 97.06, 69.84, 67.98, 75.57, 99.13, 81.59, 84.85, 81.67, 69.69, 66.12, 63.22, 79.35, 89.57, 66.3, 80.28, 85.74, 56.87, 95.26, 87.06, 77.39, 52.24, 76.29, 56.63, 98.5, 92.97, 57.29, 56.66, 96.19, 64.61, 90.92, 81.21, 77.66, 88.04, 59.93, 59.88, 91.76, 77.94, 96.53, 88.38, 67.09, 88.47, 63.51, 55.6, 91.51, 52.87, 75.14, 60.11, 55.76, 66.3, 63.57, 87.3, 67.04, 77.68, 80.87, 50.16, 79.82, 90.65, 72.56, 64.58, 93.62]
# la media de la fabrica 2 es => 74.7226
# la mediana de la fabrica 2 es => 76.43
# la moda de la fabrica 2 es => 66.3
