# %% [markdown]
# <a href="https://colab.research.google.com/github/HgVv19/Probyestadistica/blob/main/Unidad1/practica_3_m%C3%A1ximo%2C_min%C3%ADmo%2C_rango_y_dispersi%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range (100):
    numero_aleatorio = round ( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [95.62, 58.21, 64.39, 69.53, 54.67, 62.31, 58.09, 93.12, 63.85, 53.14, 70.54, 84.57, 99.85, 52.92, 65.5, 82.98, 81.83, 72.36, 69.71, 75.18, 79.59, 86.45, 74.91, 65.85, 72.3, 66.03, 66.32, 56.2, 58.43, 98.19, 95.46, 74.52, 67.26, 90.21, 86.27, 57.94, 53.28, 97.58, 86.18, 86.08, 98.98, 74.62, 51.98, 50.17, 93.02, 74.59, 79.24, 96.89, 55.2, 70.83, 67.14, 98.28, 60.16, 68.48, 94.86, 71.39, 92.09, 69.98, 56.02, 79.07, 52.23, 75.07, 98.56, 53.1, 76.78, 85.92, 52.7, 81.53, 94.52, 91.23, 99.77, 97.54, 69.65, 85.0, 62.01, 78.73, 74.6, 50.98, 86.1, 82.26, 55.99, 95.96, 66.95, 69.07, 81.11, 75.94, 82.13, 64.35, 56.57, 77.25, 79.71, 83.53, 50.22, 55.21, 79.68, 73.21, 70.75, 89.03, 82.5, 66.13]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio = round ( random.uniform(50, 100), 2 )
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [55.45, 84.52, 74.13, 97.91, 88.62, 92.42, 89.29, 95.89, 60.49, 77.89, 79.32, 86.19, 80.57, 53.64, 77.7, 89.94, 92.78, 84.44, 87.28, 55.91, 71.3, 59.98, 68.46, 66.91, 68.19, 79.91, 58.11, 78.64, 81.68, 95.84, 94.26, 75.38, 76.14, 57.16, 50.65, 80.75, 54.69, 81.01, 79.36, 94.31, 65.44, 83.73, 59.1, 54.2, 57.42, 91.66, 50.38, 54.07, 72.67, 65.7, 61.98, 94.74, 93.46, 68.94, 69.18, 63.09, 71.35, 52.55, 78.28, 51.14, 78.07, 62.96, 52.79, 91.2, 97.78, 57.61, 79.93, 78.77, 62.97, 56.43, 85.79, 79.34, 55.78, 73.11, 71.71, 90.58, 77.59, 75.31, 80.78, 81.82, 69.78, 67.41, 65.99, 51.48, 81.72, 64.14, 97.01, 63.32, 78.97, 77.93, 61.32, 86.81, 60.75, 92.81, 63.14, 52.18, 95.85, 92.79, 73.97, 72.47]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 =  maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print( "Estadistica descrptiva de la fabrica 1 \n", "Media =", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
       "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descrptiva de la fabrica 1
#  Media = 74.5398
#  Mediana = 74.595
#  Moda = 95.62
#  Maximo = 99.85
#  Minimo = 50.17
#  Rango = 49.67999999999999

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 =  maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadistica descrptiva de la fabrica 2 \n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
       "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descrptiva de la fabrica 2
#  Media = 73.9635
#  Mediana = 75.345
#  Moda = 55.45
#  Maximo = 97.91
#  Minimo = 50.38
#  Rango = 47.529999999999994

# %% [markdown]
# Dispersión de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.524106675010023

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 13.876188337500244

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1,  color='b', linestyle='dashed', linewidth=2, label=f'Media=(media1:,2f)')
plt.figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1,  color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar= {desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2) # removed the extra indent on this line

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2,  color='b', linestyle='dashed', linewidth=2, label=f'Media=(media2:,2f)')
plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2,  color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar= {desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %% [markdown]
# Densidad

# %%
import seaborn as sns

# %%
sns.histplot(x=fabrica1, kde=True, kde_kws={'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
