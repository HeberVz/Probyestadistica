# %% [markdown]
# <a href="https://colab.research.google.com/github/HeberVz/Probyestadistica/blob/main/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as mt
from itertools import permutations
from itertools import product
import numpy as np

# %%
mt.factorial(10)
# Out:
# 3628800

# %%
mt.factorial(6)
# Out:
# 720

# %%
3628800 / 720
# Out:
# 5040.0

# %%
asistentes = ["Asis1", "Asis2", "Asis3", "Asis4", "Asis5", "Asis6", "Asis7", "Asis8", "Asis9", "Asis10"]

n = len(asistentes)
r = 4

Pr = mt.factorial(n) / (mt.factorial(n-r))

print("Existen ", Pr, " posibles combinaciones sin repetición del total de ",
      n, "Asistentes ", " en grupos de ", r, " en ", r)
print("Aquí las permutaciones")
permutaciones_asistentes = list(permutations(asistentes, r))

for permutacion in permutaciones_asistentes:
    print(permutacion)
# Out:
# Existen  5040.0  posibles combinaciones sin repetición del total de  10 Asistentes   en grupos de  4  en  4
# Aquí las permutaciones
# ('Asis1', 'Asis2', 'Asis3', 'Asis4')
# ('Asis1', 'Asis2', 'Asis3', 'Asis5')
# ('Asis1', 'Asis2', 'Asis3', 'Asis6')
# ('Asis1', 'Asis2', 'Asis3', 'Asis7')
# ('Asis1', 'Asis2', 'Asis3', 'Asis8')
# ('Asis1', 'Asis2', 'Asis3', 'Asis9')
# ('Asis1', 'Asis2', 'Asis3', 'Asis10')
# ('Asis1', 'Asis2', 'Asis4', 'Asis3')
# ('Asis1', 'Asis2', 'Asis4', 'Asis5')
# ('Asis1', 'Asis2', 'Asis4', 'Asis6')
# ('Asis1', 'Asis2', 'Asis4', 'Asis7')
# ('Asis1', 'Asis2', 'Asis4', 'Asis8')
# ('Asis1', 'Asis2', 'Asis4', 'Asis9')
# ('Asis1', 'Asis2', 'Asis4', 'Asis10')
# ('Asis1', 'Asis2', 'Asis5', 'Asis3')
# ('Asis1', 'Asis2', 'Asis5', 'Asis4')
# ('Asis1', 'Asis2', 'Asis5', 'Asis6')
# ('Asis1', 'Asis2', 'Asis5', 'Asis7')
# ('Asis1', 'Asis2', 'Asis5', 'Asis8')
# ('Asis1', 'Asis2', 'Asis5', 'Asis9')
# ('Asis1', 'Asis2', 'Asis5', 'Asis10')
# ('Asis1', 'Asis2', 'Asis6', 'Asis3')
# ...
